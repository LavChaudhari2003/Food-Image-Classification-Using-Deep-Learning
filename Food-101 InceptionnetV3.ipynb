# %%
# !pip install keras==2.15.0
# Out:
# Requirement already satisfied: keras==2.15.0 in /opt/conda/lib/python3.10/site-packages (2.15.0)

# %%
import keras
keras.__version__
# Out:
# '2.15.0'

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import vgg16
from keras.src.layers.pooling.average_pooling2d import AvgPool2D
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dropout
from keras.models import Sequential
from keras.layers import Dense,Input,Flatten
from tensorflow.keras.utils import load_img,img_to_array
from sklearn.metrics import confusion_matrix
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# %%
import os
print(os.listdir("/kaggle/input/food-101/food-101/food-101/images/"))
# Out:
# ['macarons', 'french_toast', 'lobster_bisque', 'prime_rib', 'pork_chop', 'guacamole', 'baby_back_ribs', 'mussels', 'beef_carpaccio', 'poutine', 'hot_and_sour_soup', 'seaweed_salad', 'foie_gras', 'dumplings', 'peking_duck', 'takoyaki', 'bibimbap', 'falafel', 'pulled_pork_sandwich', 'lobster_roll_sandwich', 'carrot_cake', 'beet_salad', 'panna_cotta', 'donuts', 'red_velvet_cake', 'grilled_cheese_sandwich', 'cannoli', 'spring_rolls', 'shrimp_and_grits', 'clam_chowder', 'omelette', 'fried_calamari', 'caprese_salad', 'oysters', 'scallops', 'ramen', 'grilled_salmon', 'croque_madame', 'filet_mignon', 'hamburger', 'spaghetti_carbonara', 'miso_soup', 'bread_pudding', 'lasagna', 'crab_cakes', 'cheesecake', 'spaghetti_bolognese', 'cup_cakes', 'creme_brulee', 'waffles', 'fish_and_chips', 'paella', 'macaroni_and_cheese', 'chocolate_mousse', 'ravioli', 'chicken_curry', 'caesar_salad', 'nachos', 'tiramisu', 'frozen_yogurt', 'ice_cream', 'risotto', 'club_sandwich', 'strawberry_shortcake', 'steak', 'churros', 'garlic_bread', 'baklava', 'bruschetta', 'hummus', 'chicken_wings', 'greek_salad', 'tuna_tartare', 'chocolate_cake', 'gyoza', 'eggs_benedict', 'deviled_eggs', 'samosa', 'sushi', 'breakfast_burrito', 'ceviche', 'beef_tartare', 'apple_pie', '.DS_Store', 'huevos_rancheros', 'beignets', 'pizza', 'edamame', 'french_onion_soup', 'hot_dog', 'tacos', 'chicken_quesadilla', 'pho', 'gnocchi', 'pancakes', 'fried_rice', 'cheese_plate', 'onion_rings', 'escargots', 'sashimi', 'pad_thai', 'french_fries']

# %% [markdown]
# ---

# %% [markdown]
# Food Classes

# %%
values = ['macarons', 'french_toast', 'lobster_bisque', 'prime_rib', 'pork_chop', 'guacamole', 'baby_back_ribs', 'mussels', 'beef_carpaccio', 'poutine', 'hot_and_sour_soup', 'seaweed_salad', 'foie_gras', 'dumplings', 'peking_duck', 'takoyaki', 'bibimbap', 'falafel', 'pulled_pork_sandwich', 'lobster_roll_sandwich', 'carrot_cake', 'beet_salad', 'panna_cotta', 'donuts', 'red_velvet_cake', 'grilled_cheese_sandwich', 'cannoli', 'spring_rolls', 'shrimp_and_grits', 'clam_chowder', 'omelette', 'fried_calamari', 'caprese_salad', 'oysters', 'scallops', 'ramen', 'grilled_salmon', 'croque_madame', 'filet_mignon', 'hamburger', 'spaghetti_carbonara', 'miso_soup', 'bread_pudding', 'lasagna', 'crab_cakes', 'cheesecake', 'spaghetti_bolognese', 'cup_cakes', 'creme_brulee', 'waffles', 'fish_and_chips', 'paella', 'macaroni_and_cheese', 'chocolate_mousse', 'ravioli', 'chicken_curry', 'caesar_salad', 'nachos', 'tiramisu', 'frozen_yogurt', 'ice_cream', 'risotto', 'club_sandwich', 'strawberry_shortcake', 'steak', 'churros', 'garlic_bread', 'baklava', 'bruschetta', 'hummus', 'chicken_wings', 'greek_salad', 'tuna_tartare', 'chocolate_cake', 'gyoza', 'eggs_benedict', 'deviled_eggs', 'samosa', 'sushi', 'breakfast_burrito', 'ceviche', 'beef_tartare', 'apple_pie', '.DS_Store', 'huevos_rancheros', 'beignets', 'pizza', 'edamame', 'french_onion_soup', 'hot_dog', 'tacos', 'chicken_quesadilla', 'pho', 'gnocchi', 'pancakes', 'fried_rice', 'cheese_plate', 'onion_rings', 'escargots', 'sashimi', 'pad_thai', 'french_fries']
values.sort()
values = values[1:]
print(values)
# Out:
# ['apple_pie', 'baby_back_ribs', 'baklava', 'beef_carpaccio', 'beef_tartare', 'beet_salad', 'beignets', 'bibimbap', 'bread_pudding', 'breakfast_burrito', 'bruschetta', 'caesar_salad', 'cannoli', 'caprese_salad', 'carrot_cake', 'ceviche', 'cheese_plate', 'cheesecake', 'chicken_curry', 'chicken_quesadilla', 'chicken_wings', 'chocolate_cake', 'chocolate_mousse', 'churros', 'clam_chowder', 'club_sandwich', 'crab_cakes', 'creme_brulee', 'croque_madame', 'cup_cakes', 'deviled_eggs', 'donuts', 'dumplings', 'edamame', 'eggs_benedict', 'escargots', 'falafel', 'filet_mignon', 'fish_and_chips', 'foie_gras', 'french_fries', 'french_onion_soup', 'french_toast', 'fried_calamari', 'fried_rice', 'frozen_yogurt', 'garlic_bread', 'gnocchi', 'greek_salad', 'grilled_cheese_sandwich', 'grilled_salmon', 'guacamole', 'gyoza', 'hamburger', 'hot_and_sour_soup', 'hot_dog', 'huevos_rancheros', 'hummus', 'ice_cream', 'lasagna', 'lobster_bisque', 'lobster_roll_sandwich', 'macaroni_and_cheese', 'macarons', 'miso_soup', 'mussels', 'nachos', 'omelette', 'onion_rings', 'oysters', 'pad_thai', 'paella', 'pancakes', 'panna_cotta', 'peking_duck', 'pho', 'pizza', 'pork_chop', 'poutine', 'prime_rib', 'pulled_pork_sandwich', 'ramen', 'ravioli', 'red_velvet_cake', 'risotto', 'samosa', 'sashimi', 'scallops', 'seaweed_salad', 'shrimp_and_grits', 'spaghetti_bolognese', 'spaghetti_carbonara', 'spring_rolls', 'steak', 'strawberry_shortcake', 'sushi', 'tacos', 'takoyaki', 'tiramisu', 'tuna_tartare', 'waffles']

# %%
train_datagen = ImageDataGenerator(rescale=1./255,validation_split=0.1)
train_data = train_datagen.flow_from_directory('/kaggle/input/food-101/food-101/food-101/images/',
                                               target_size=(299,299),
                                               batch_size=100,
                                               class_mode='categorical',
                                               shuffle=True,
                                               subset='training')
test_data = train_datagen.flow_from_directory('/kaggle/input/food-101/food-101/food-101/images/',
                                               target_size=(224,224),
                                               batch_size=100,
                                               class_mode='categorical',
                                               shuffle=False,
                                               subset='validation')
# Out:
# Found 90900 images belonging to 101 classes.
# Found 10100 images belonging to 101 classes.

# %%
print('\nBatch Size:',100,
     "\nNunmber of Batches in training set:",len(train_data),
     "\nNunmber of Batches in testing set:",len(test_data),
     "\nNumber of Samples in training set:",train_data.samples,"Samples",
     "\nNumber of Samples in testing set:",test_data.samples,"Samples")
# Out:
# Batch Size: 100
# Nunmber of Batches in training set: 909
# Nunmber of Batches in testing set: 101
# Number of Samples in training set: 90900 Samples
# Number of Samples in testing set: 10100 Samples

# %% [markdown]
# # Model - Inception V3 Architecture

# %%
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input, decode_predictions
from keras.preprocessing import image
from keras.layers import Input
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D, AveragePooling2D
from keras.callbacks import ModelCheckpoint, CSVLogger, LearningRateScheduler, ReduceLROnPlateau
from keras.optimizers import SGD
from keras.regularizers import l2
import keras.backend as K
import math

# %%
base_model3 = InceptionV3(weights='imagenet', include_top=False, input_tensor=Input(shape=(299, 299, 3)))

x = base_model3.output
x = AveragePooling2D()(x)
x = Dropout(.5)(x)
x = Flatten()(x)
x = Dense(101, kernel_initializer='glorot_uniform', kernel_regularizer=l2(.0005), activation='softmax')(x)
model3 = Model(inputs=base_model3.input, outputs=x)
model3.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_15 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  conv2d_1034 (Conv2D)        (None, 111, 111, 32)         864       ['input_15[0][0]']
#
#  batch_normalization_1034 (  (None, 111, 111, 32)         96        ['conv2d_1034[0][0]']
#  BatchNormalization)
#
#  activation_1034 (Activatio  (None, 111, 111, 32)         0         ['batch_normalization_1034[0][
#  n)                                                                 0]']
#
#  conv2d_1035 (Conv2D)        (None, 109, 109, 32)         9216      ['activation_1034[0][0]']
#
#  batch_normalization_1035 (  (None, 109, 109, 32)         96        ['conv2d_1035[0][0]']
#  BatchNormalization)
#
#  activation_1035 (Activatio  (None, 109, 109, 32)         0         ['batch_normalization_1035[0][
#  n)                                                                 0]']
#
#  conv2d_1036 (Conv2D)        (None, 109, 109, 64)         18432     ['activation_1035[0][0]']
#
#  batch_normalization_1036 (  (None, 109, 109, 64)         192       ['conv2d_1036[0][0]']
#  BatchNormalization)
#
#  activation_1036 (Activatio  (None, 109, 109, 64)         0         ['batch_normalization_1036[0][
#  n)                                                                 0]']
#
#  max_pooling2d_44 (MaxPooli  (None, 54, 54, 64)           0         ['activation_1036[0][0]']
#  ng2D)
#
#  conv2d_1037 (Conv2D)        (None, 54, 54, 80)           5120      ['max_pooling2d_44[0][0]']
#
#  batch_normalization_1037 (  (None, 54, 54, 80)           240       ['conv2d_1037[0][0]']
#  BatchNormalization)
#
#  activation_1037 (Activatio  (None, 54, 54, 80)           0         ['batch_normalization_1037[0][
#  n)                                                                 0]']
#
#  conv2d_1038 (Conv2D)        (None, 52, 52, 192)          138240    ['activation_1037[0][0]']
#
#  batch_normalization_1038 (  (None, 52, 52, 192)          576       ['conv2d_1038[0][0]']
#  BatchNormalization)
#
#  activation_1038 (Activatio  (None, 52, 52, 192)          0         ['batch_normalization_1038[0][
#  n)                                                                 0]']
#
#  max_pooling2d_45 (MaxPooli  (None, 25, 25, 192)          0         ['activation_1038[0][0]']
#  ng2D)
#
#  conv2d_1042 (Conv2D)        (None, 25, 25, 64)           12288     ['max_pooling2d_45[0][0]']
#
#  batch_normalization_1042 (  (None, 25, 25, 64)           192       ['conv2d_1042[0][0]']
#  BatchNormalization)
#
#  activation_1042 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_1042[0][
#  n)                                                                 0]']
#
#  conv2d_1040 (Conv2D)        (None, 25, 25, 48)           9216      ['max_pooling2d_45[0][0]']
#
#  conv2d_1043 (Conv2D)        (None, 25, 25, 96)           55296     ['activation_1042[0][0]']
#
#  batch_normalization_1040 (  (None, 25, 25, 48)           144       ['conv2d_1040[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1043 (  (None, 25, 25, 96)           288       ['conv2d_1043[0][0]']
#  BatchNormalization)
#
#  activation_1040 (Activatio  (None, 25, 25, 48)           0         ['batch_normalization_1040[0][
#  n)                                                                 0]']
#
#  activation_1043 (Activatio  (None, 25, 25, 96)           0         ['batch_normalization_1043[0][
#  n)                                                                 0]']
#
#  average_pooling2d_109 (Ave  (None, 25, 25, 192)          0         ['max_pooling2d_45[0][0]']
#  ragePooling2D)
#
#  conv2d_1039 (Conv2D)        (None, 25, 25, 64)           12288     ['max_pooling2d_45[0][0]']
#
#  conv2d_1041 (Conv2D)        (None, 25, 25, 64)           76800     ['activation_1040[0][0]']
#
#  conv2d_1044 (Conv2D)        (None, 25, 25, 96)           82944     ['activation_1043[0][0]']
#
#  conv2d_1045 (Conv2D)        (None, 25, 25, 32)           6144      ['average_pooling2d_109[0][0]'
#                                                                     ]
#
#  batch_normalization_1039 (  (None, 25, 25, 64)           192       ['conv2d_1039[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1041 (  (None, 25, 25, 64)           192       ['conv2d_1041[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1044 (  (None, 25, 25, 96)           288       ['conv2d_1044[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1045 (  (None, 25, 25, 32)           96        ['conv2d_1045[0][0]']
#  BatchNormalization)
#
#  activation_1039 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_1039[0][
#  n)                                                                 0]']
#
#  activation_1041 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_1041[0][
#  n)                                                                 0]']
#
#  activation_1044 (Activatio  (None, 25, 25, 96)           0         ['batch_normalization_1044[0][
#  n)                                                                 0]']
#
#  activation_1045 (Activatio  (None, 25, 25, 32)           0         ['batch_normalization_1045[0][
#  n)                                                                 0]']
#
#  mixed0 (Concatenate)        (None, 25, 25, 256)          0         ['activation_1039[0][0]',
#                                                                      'activation_1041[0][0]',
#                                                                      'activation_1044[0][0]',
#                                                                      'activation_1045[0][0]']
#
#  conv2d_1049 (Conv2D)        (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_1049 (  (None, 25, 25, 64)           192       ['conv2d_1049[0][0]']
#  BatchNormalization)
#
#  activation_1049 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_1049[0][
#  n)                                                                 0]']
#
#  conv2d_1047 (Conv2D)        (None, 25, 25, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_1050 (Conv2D)        (None, 25, 25, 96)           55296     ['activation_1049[0][0]']
#
#  batch_normalization_1047 (  (None, 25, 25, 48)           144       ['conv2d_1047[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1050 (  (None, 25, 25, 96)           288       ['conv2d_1050[0][0]']
#  BatchNormalization)
#
#  activation_1047 (Activatio  (None, 25, 25, 48)           0         ['batch_normalization_1047[0][
#  n)                                                                 0]']
#
#  activation_1050 (Activatio  (None, 25, 25, 96)           0         ['batch_normalization_1050[0][
#  n)                                                                 0]']
#
#  average_pooling2d_110 (Ave  (None, 25, 25, 256)          0         ['mixed0[0][0]']
#  ragePooling2D)
#
#  conv2d_1046 (Conv2D)        (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_1048 (Conv2D)        (None, 25, 25, 64)           76800     ['activation_1047[0][0]']
#
#  conv2d_1051 (Conv2D)        (None, 25, 25, 96)           82944     ['activation_1050[0][0]']
#
#  conv2d_1052 (Conv2D)        (None, 25, 25, 64)           16384     ['average_pooling2d_110[0][0]'
#                                                                     ]
#
#  batch_normalization_1046 (  (None, 25, 25, 64)           192       ['conv2d_1046[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1048 (  (None, 25, 25, 64)           192       ['conv2d_1048[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1051 (  (None, 25, 25, 96)           288       ['conv2d_1051[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1052 (  (None, 25, 25, 64)           192       ['conv2d_1052[0][0]']
#  BatchNormalization)
#
#  activation_1046 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_1046[0][
#  n)                                                                 0]']
#
#  activation_1048 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_1048[0][
#  n)                                                                 0]']
#
#  activation_1051 (Activatio  (None, 25, 25, 96)           0         ['batch_normalization_1051[0][
#  n)                                                                 0]']
#
#  activation_1052 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_1052[0][
#  n)                                                                 0]']
#
#  mixed1 (Concatenate)        (None, 25, 25, 288)          0         ['activation_1046[0][0]',
#                                                                      'activation_1048[0][0]',
#                                                                      'activation_1051[0][0]',
#                                                                      'activation_1052[0][0]']
#
#  conv2d_1056 (Conv2D)        (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_1056 (  (None, 25, 25, 64)           192       ['conv2d_1056[0][0]']
#  BatchNormalization)
#
#  activation_1056 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_1056[0][
#  n)                                                                 0]']
#
#  conv2d_1054 (Conv2D)        (None, 25, 25, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_1057 (Conv2D)        (None, 25, 25, 96)           55296     ['activation_1056[0][0]']
#
#  batch_normalization_1054 (  (None, 25, 25, 48)           144       ['conv2d_1054[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1057 (  (None, 25, 25, 96)           288       ['conv2d_1057[0][0]']
#  BatchNormalization)
#
#  activation_1054 (Activatio  (None, 25, 25, 48)           0         ['batch_normalization_1054[0][
#  n)                                                                 0]']
#
#  activation_1057 (Activatio  (None, 25, 25, 96)           0         ['batch_normalization_1057[0][
#  n)                                                                 0]']
#
#  average_pooling2d_111 (Ave  (None, 25, 25, 288)          0         ['mixed1[0][0]']
#  ragePooling2D)
#
#  conv2d_1053 (Conv2D)        (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_1055 (Conv2D)        (None, 25, 25, 64)           76800     ['activation_1054[0][0]']
#
#  conv2d_1058 (Conv2D)        (None, 25, 25, 96)           82944     ['activation_1057[0][0]']
#
#  conv2d_1059 (Conv2D)        (None, 25, 25, 64)           18432     ['average_pooling2d_111[0][0]'
#                                                                     ]
#
#  batch_normalization_1053 (  (None, 25, 25, 64)           192       ['conv2d_1053[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1055 (  (None, 25, 25, 64)           192       ['conv2d_1055[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1058 (  (None, 25, 25, 96)           288       ['conv2d_1058[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1059 (  (None, 25, 25, 64)           192       ['conv2d_1059[0][0]']
#  BatchNormalization)
#
#  activation_1053 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_1053[0][
#  n)                                                                 0]']
#
#  activation_1055 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_1055[0][
#  n)                                                                 0]']
#
#  activation_1058 (Activatio  (None, 25, 25, 96)           0         ['batch_normalization_1058[0][
#  n)                                                                 0]']
#
#  activation_1059 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_1059[0][
#  n)                                                                 0]']
#
#  mixed2 (Concatenate)        (None, 25, 25, 288)          0         ['activation_1053[0][0]',
#                                                                      'activation_1055[0][0]',
#                                                                      'activation_1058[0][0]',
#                                                                      'activation_1059[0][0]']
#
#  conv2d_1061 (Conv2D)        (None, 25, 25, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_1061 (  (None, 25, 25, 64)           192       ['conv2d_1061[0][0]']
#  BatchNormalization)
#
#  activation_1061 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_1061[0][
#  n)                                                                 0]']
#
#  conv2d_1062 (Conv2D)        (None, 25, 25, 96)           55296     ['activation_1061[0][0]']
#
#  batch_normalization_1062 (  (None, 25, 25, 96)           288       ['conv2d_1062[0][0]']
#  BatchNormalization)
#
#  activation_1062 (Activatio  (None, 25, 25, 96)           0         ['batch_normalization_1062[0][
#  n)                                                                 0]']
#
#  conv2d_1060 (Conv2D)        (None, 12, 12, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_1063 (Conv2D)        (None, 12, 12, 96)           82944     ['activation_1062[0][0]']
#
#  batch_normalization_1060 (  (None, 12, 12, 384)          1152      ['conv2d_1060[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1063 (  (None, 12, 12, 96)           288       ['conv2d_1063[0][0]']
#  BatchNormalization)
#
#  activation_1060 (Activatio  (None, 12, 12, 384)          0         ['batch_normalization_1060[0][
#  n)                                                                 0]']
#
#  activation_1063 (Activatio  (None, 12, 12, 96)           0         ['batch_normalization_1063[0][
#  n)                                                                 0]']
#
#  max_pooling2d_46 (MaxPooli  (None, 12, 12, 288)          0         ['mixed2[0][0]']
#  ng2D)
#
#  mixed3 (Concatenate)        (None, 12, 12, 768)          0         ['activation_1060[0][0]',
#                                                                      'activation_1063[0][0]',
#                                                                      'max_pooling2d_46[0][0]']
#
#  conv2d_1068 (Conv2D)        (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_1068 (  (None, 12, 12, 128)          384       ['conv2d_1068[0][0]']
#  BatchNormalization)
#
#  activation_1068 (Activatio  (None, 12, 12, 128)          0         ['batch_normalization_1068[0][
#  n)                                                                 0]']
#
#  conv2d_1069 (Conv2D)        (None, 12, 12, 128)          114688    ['activation_1068[0][0]']
#
#  batch_normalization_1069 (  (None, 12, 12, 128)          384       ['conv2d_1069[0][0]']
#  BatchNormalization)
#
#  activation_1069 (Activatio  (None, 12, 12, 128)          0         ['batch_normalization_1069[0][
#  n)                                                                 0]']
#
#  conv2d_1065 (Conv2D)        (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_1070 (Conv2D)        (None, 12, 12, 128)          114688    ['activation_1069[0][0]']
#
#  batch_normalization_1065 (  (None, 12, 12, 128)          384       ['conv2d_1065[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1070 (  (None, 12, 12, 128)          384       ['conv2d_1070[0][0]']
#  BatchNormalization)
#
#  activation_1065 (Activatio  (None, 12, 12, 128)          0         ['batch_normalization_1065[0][
#  n)                                                                 0]']
#
#  activation_1070 (Activatio  (None, 12, 12, 128)          0         ['batch_normalization_1070[0][
#  n)                                                                 0]']
#
#  conv2d_1066 (Conv2D)        (None, 12, 12, 128)          114688    ['activation_1065[0][0]']
#
#  conv2d_1071 (Conv2D)        (None, 12, 12, 128)          114688    ['activation_1070[0][0]']
#
#  batch_normalization_1066 (  (None, 12, 12, 128)          384       ['conv2d_1066[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1071 (  (None, 12, 12, 128)          384       ['conv2d_1071[0][0]']
#  BatchNormalization)
#
#  activation_1066 (Activatio  (None, 12, 12, 128)          0         ['batch_normalization_1066[0][
#  n)                                                                 0]']
#
#  activation_1071 (Activatio  (None, 12, 12, 128)          0         ['batch_normalization_1071[0][
#  n)                                                                 0]']
#
#  average_pooling2d_112 (Ave  (None, 12, 12, 768)          0         ['mixed3[0][0]']
#  ragePooling2D)
#
#  conv2d_1064 (Conv2D)        (None, 12, 12, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_1067 (Conv2D)        (None, 12, 12, 192)          172032    ['activation_1066[0][0]']
#
#  conv2d_1072 (Conv2D)        (None, 12, 12, 192)          172032    ['activation_1071[0][0]']
#
#  conv2d_1073 (Conv2D)        (None, 12, 12, 192)          147456    ['average_pooling2d_112[0][0]'
#                                                                     ]
#
#  batch_normalization_1064 (  (None, 12, 12, 192)          576       ['conv2d_1064[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1067 (  (None, 12, 12, 192)          576       ['conv2d_1067[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1072 (  (None, 12, 12, 192)          576       ['conv2d_1072[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1073 (  (None, 12, 12, 192)          576       ['conv2d_1073[0][0]']
#  BatchNormalization)
#
#  activation_1064 (Activatio  (None, 12, 12, 192)          0         ['batch_normalization_1064[0][
#  n)                                                                 0]']
#
#  activation_1067 (Activatio  (None, 12, 12, 192)          0         ['batch_normalization_1067[0][
#  n)                                                                 0]']
#
#  activation_1072 (Activatio  (None, 12, 12, 192)          0         ['batch_normalization_1072[0][
#  n)                                                                 0]']
#
#  activation_1073 (Activatio  (None, 12, 12, 192)          0         ['batch_normalization_1073[0][
#  n)                                                                 0]']
#
#  mixed4 (Concatenate)        (None, 12, 12, 768)          0         ['activation_1064[0][0]',
#                                                                      'activation_1067[0][0]',
#                                                                      'activation_1072[0][0]',
#                                                                      'activation_1073[0][0]']
#
#  conv2d_1078 (Conv2D)        (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_1078 (  (None, 12, 12, 160)          480       ['conv2d_1078[0][0]']
#  BatchNormalization)
#
#  activation_1078 (Activatio  (None, 12, 12, 160)          0         ['batch_normalization_1078[0][
#  n)                                                                 0]']
#
#  conv2d_1079 (Conv2D)        (None, 12, 12, 160)          179200    ['activation_1078[0][0]']
#
#  batch_normalization_1079 (  (None, 12, 12, 160)          480       ['conv2d_1079[0][0]']
#  BatchNormalization)
#
#  activation_1079 (Activatio  (None, 12, 12, 160)          0         ['batch_normalization_1079[0][
#  n)                                                                 0]']
#
#  conv2d_1075 (Conv2D)        (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_1080 (Conv2D)        (None, 12, 12, 160)          179200    ['activation_1079[0][0]']
#
#  batch_normalization_1075 (  (None, 12, 12, 160)          480       ['conv2d_1075[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1080 (  (None, 12, 12, 160)          480       ['conv2d_1080[0][0]']
#  BatchNormalization)
#
#  activation_1075 (Activatio  (None, 12, 12, 160)          0         ['batch_normalization_1075[0][
#  n)                                                                 0]']
#
#  activation_1080 (Activatio  (None, 12, 12, 160)          0         ['batch_normalization_1080[0][
#  n)                                                                 0]']
#
#  conv2d_1076 (Conv2D)        (None, 12, 12, 160)          179200    ['activation_1075[0][0]']
#
#  conv2d_1081 (Conv2D)        (None, 12, 12, 160)          179200    ['activation_1080[0][0]']
#
#  batch_normalization_1076 (  (None, 12, 12, 160)          480       ['conv2d_1076[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1081 (  (None, 12, 12, 160)          480       ['conv2d_1081[0][0]']
#  BatchNormalization)
#
#  activation_1076 (Activatio  (None, 12, 12, 160)          0         ['batch_normalization_1076[0][
#  n)                                                                 0]']
#
#  activation_1081 (Activatio  (None, 12, 12, 160)          0         ['batch_normalization_1081[0][
#  n)                                                                 0]']
#
#  average_pooling2d_113 (Ave  (None, 12, 12, 768)          0         ['mixed4[0][0]']
#  ragePooling2D)
#
#  conv2d_1074 (Conv2D)        (None, 12, 12, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_1077 (Conv2D)        (None, 12, 12, 192)          215040    ['activation_1076[0][0]']
#
#  conv2d_1082 (Conv2D)        (None, 12, 12, 192)          215040    ['activation_1081[0][0]']
#
#  conv2d_1083 (Conv2D)        (None, 12, 12, 192)          147456    ['average_pooling2d_113[0][0]'
#                                                                     ]
#
#  batch_normalization_1074 (  (None, 12, 12, 192)          576       ['conv2d_1074[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1077 (  (None, 12, 12, 192)          576       ['conv2d_1077[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1082 (  (None, 12, 12, 192)          576       ['conv2d_1082[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1083 (  (None, 12, 12, 192)          576       ['conv2d_1083[0][0]']
#  BatchNormalization)
#
#  activation_1074 (Activatio  (None, 12, 12, 192)          0         ['batch_normalization_1074[0][
#  n)                                                                 0]']
#
#  activation_1077 (Activatio  (None, 12, 12, 192)          0         ['batch_normalization_1077[0][
#  n)                                                                 0]']
#
#  activation_1082 (Activatio  (None, 12, 12, 192)          0         ['batch_normalization_1082[0][
#  n)                                                                 0]']
#
#  activation_1083 (Activatio  (None, 12, 12, 192)          0         ['batch_normalization_1083[0][
#  n)                                                                 0]']
#
#  mixed5 (Concatenate)        (None, 12, 12, 768)          0         ['activation_1074[0][0]',
#                                                                      'activation_1077[0][0]',
#                                                                      'activation_1082[0][0]',
#                                                                      'activation_1083[0][0]']
#
#  conv2d_1088 (Conv2D)        (None, 12, 12, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_1088 (  (None, 12, 12, 160)          480       ['conv2d_1088[0][0]']
#  BatchNormalization)
#
#  activation_1088 (Activatio  (None, 12, 12, 160)          0         ['batch_normalization_1088[0][
#  n)                                                                 0]']
#
#  conv2d_1089 (Conv2D)        (None, 12, 12, 160)          179200    ['activation_1088[0][0]']
#
#  batch_normalization_1089 (  (None, 12, 12, 160)          480       ['conv2d_1089[0][0]']
#  BatchNormalization)
#
#  activation_1089 (Activatio  (None, 12, 12, 160)          0         ['batch_normalization_1089[0][
#  n)                                                                 0]']
#
#  conv2d_1085 (Conv2D)        (None, 12, 12, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_1090 (Conv2D)        (None, 12, 12, 160)          179200    ['activation_1089[0][0]']
#
#  batch_normalization_1085 (  (None, 12, 12, 160)          480       ['conv2d_1085[0][0]']
# ...
#  conv2d_1113 (Conv2D)        (None, 5, 5, 384)            442368    ['activation_1111[0][0]']
#
#  conv2d_1116 (Conv2D)        (None, 5, 5, 384)            442368    ['activation_1115[0][0]']
#
#  conv2d_1117 (Conv2D)        (None, 5, 5, 384)            442368    ['activation_1115[0][0]']
#
#  average_pooling2d_116 (Ave  (None, 5, 5, 1280)           0         ['mixed8[0][0]']
#  ragePooling2D)
#
#  conv2d_1110 (Conv2D)        (None, 5, 5, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_1112 (  (None, 5, 5, 384)            1152      ['conv2d_1112[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1113 (  (None, 5, 5, 384)            1152      ['conv2d_1113[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1116 (  (None, 5, 5, 384)            1152      ['conv2d_1116[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1117 (  (None, 5, 5, 384)            1152      ['conv2d_1117[0][0]']
#  BatchNormalization)
#
#  conv2d_1118 (Conv2D)        (None, 5, 5, 192)            245760    ['average_pooling2d_116[0][0]'
#                                                                     ]
#
#  batch_normalization_1110 (  (None, 5, 5, 320)            960       ['conv2d_1110[0][0]']
#  BatchNormalization)
#
#  activation_1112 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_1112[0][
#  n)                                                                 0]']
#
#  activation_1113 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_1113[0][
#  n)                                                                 0]']
#
#  activation_1116 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_1116[0][
#  n)                                                                 0]']
#
#  activation_1117 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_1117[0][
#  n)                                                                 0]']
#
#  batch_normalization_1118 (  (None, 5, 5, 192)            576       ['conv2d_1118[0][0]']
#  BatchNormalization)
#
#  activation_1110 (Activatio  (None, 5, 5, 320)            0         ['batch_normalization_1110[0][
#  n)                                                                 0]']
#
#  mixed9_0 (Concatenate)      (None, 5, 5, 768)            0         ['activation_1112[0][0]',
#                                                                      'activation_1113[0][0]']
#
#  concatenate_22 (Concatenat  (None, 5, 5, 768)            0         ['activation_1116[0][0]',
#  e)                                                                  'activation_1117[0][0]']
#
#  activation_1118 (Activatio  (None, 5, 5, 192)            0         ['batch_normalization_1118[0][
#  n)                                                                 0]']
#
#  mixed9 (Concatenate)        (None, 5, 5, 2048)           0         ['activation_1110[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_22[0][0]',
#                                                                      'activation_1118[0][0]']
#
#  conv2d_1123 (Conv2D)        (None, 5, 5, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_1123 (  (None, 5, 5, 448)            1344      ['conv2d_1123[0][0]']
#  BatchNormalization)
#
#  activation_1123 (Activatio  (None, 5, 5, 448)            0         ['batch_normalization_1123[0][
#  n)                                                                 0]']
#
#  conv2d_1120 (Conv2D)        (None, 5, 5, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_1124 (Conv2D)        (None, 5, 5, 384)            1548288   ['activation_1123[0][0]']
#
#  batch_normalization_1120 (  (None, 5, 5, 384)            1152      ['conv2d_1120[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1124 (  (None, 5, 5, 384)            1152      ['conv2d_1124[0][0]']
#  BatchNormalization)
#
#  activation_1120 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_1120[0][
#  n)                                                                 0]']
#
#  activation_1124 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_1124[0][
#  n)                                                                 0]']
#
#  conv2d_1121 (Conv2D)        (None, 5, 5, 384)            442368    ['activation_1120[0][0]']
#
#  conv2d_1122 (Conv2D)        (None, 5, 5, 384)            442368    ['activation_1120[0][0]']
#
#  conv2d_1125 (Conv2D)        (None, 5, 5, 384)            442368    ['activation_1124[0][0]']
#
#  conv2d_1126 (Conv2D)        (None, 5, 5, 384)            442368    ['activation_1124[0][0]']
#
#  average_pooling2d_117 (Ave  (None, 5, 5, 2048)           0         ['mixed9[0][0]']
#  ragePooling2D)
#
#  conv2d_1119 (Conv2D)        (None, 5, 5, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_1121 (  (None, 5, 5, 384)            1152      ['conv2d_1121[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1122 (  (None, 5, 5, 384)            1152      ['conv2d_1122[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1125 (  (None, 5, 5, 384)            1152      ['conv2d_1125[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1126 (  (None, 5, 5, 384)            1152      ['conv2d_1126[0][0]']
#  BatchNormalization)
#
#  conv2d_1127 (Conv2D)        (None, 5, 5, 192)            393216    ['average_pooling2d_117[0][0]'
#                                                                     ]
#
#  batch_normalization_1119 (  (None, 5, 5, 320)            960       ['conv2d_1119[0][0]']
#  BatchNormalization)
#
#  activation_1121 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_1121[0][
#  n)                                                                 0]']
#
#  activation_1122 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_1122[0][
#  n)                                                                 0]']
#
#  activation_1125 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_1125[0][
#  n)                                                                 0]']
#
#  activation_1126 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_1126[0][
#  n)                                                                 0]']
#
#  batch_normalization_1127 (  (None, 5, 5, 192)            576       ['conv2d_1127[0][0]']
#  BatchNormalization)
#
#  activation_1119 (Activatio  (None, 5, 5, 320)            0         ['batch_normalization_1119[0][
#  n)                                                                 0]']
#
#  mixed9_1 (Concatenate)      (None, 5, 5, 768)            0         ['activation_1121[0][0]',
#                                                                      'activation_1122[0][0]']
#
#  concatenate_23 (Concatenat  (None, 5, 5, 768)            0         ['activation_1125[0][0]',
#  e)                                                                  'activation_1126[0][0]']
#
#  activation_1127 (Activatio  (None, 5, 5, 192)            0         ['batch_normalization_1127[0][
#  n)                                                                 0]']
#
#  mixed10 (Concatenate)       (None, 5, 5, 2048)           0         ['activation_1119[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_23[0][0]',
#                                                                      'activation_1127[0][0]']
#
#  average_pooling2d_118 (Ave  (None, 2, 2, 2048)           0         ['mixed10[0][0]']
#  ragePooling2D)
#
#  dropout_11 (Dropout)        (None, 2, 2, 2048)           0         ['average_pooling2d_118[0][0]'
#                                                                     ]
#
#  flatten_12 (Flatten)        (None, 8192)                 0         ['dropout_11[0][0]']
#
#  dense_12 (Dense)            (None, 101)                  827493    ['flatten_12[0][0]']
#
# ==================================================================================================
# Total params: 22630277 (86.33 MB)
# Trainable params: 22595845 (86.20 MB)
# Non-trainable params: 34432 (134.50 KB)
# __________________________________________________________________________________________________

# %%
opt = SGD(lr=.1, momentum=.9)
model3.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.models import load_model
model3 = load_model("/kaggle/input/food-101-model/tensorflow2/food-101/1/model_food_101.h5")

# %%
from tensorflow.keras.callbacks import EarlyStopping
results3 = model3.fit(train_data, epochs=10, validation_data=test_data,
                  steps_per_epoch=len(train_data), validation_steps=len(test_data),
                  callbacks = EarlyStopping(patience=2, monitor='val_accuracy',restore_best_weights=True)
                  )
# Out:
# Epoch 1/10
# 2024-03-14 23:31:53.916425: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_1/dropout_11/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1710459118.259536     186 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 909/909 [==============================] - 1009s 1s/step - loss: 0.0816 - accuracy: 0.9924 - val_loss: 1.6280 - val_accuracy: 0.7065
# Epoch 2/10
# 909/909 [==============================] - 829s 912ms/step - loss: 0.0646 - accuracy: 0.9962 - val_loss: 1.4801 - val_accuracy: 0.7417
# Epoch 3/10
# 909/909 [==============================] - 830s 913ms/step - loss: 0.0562 - accuracy: 0.9970 - val_loss: 1.4059 - val_accuracy: 0.7487
# Epoch 4/10
# 909/909 [==============================] - 829s 911ms/step - loss: 0.0460 - accuracy: 0.9986 - val_loss: 1.3613 - val_accuracy: 0.7535
# Epoch 5/10
# 909/909 [==============================] - 828s 911ms/step - loss: 0.0379 - accuracy: 0.9995 - val_loss: 1.2399 - val_accuracy: 0.7697
# Epoch 6/10
# 909/909 [==============================] - 828s 911ms/step - loss: 0.0325 - accuracy: 0.9997 - val_loss: 1.2145 - val_accuracy: 0.7693
# Epoch 7/10
# 909/909 [==============================] - 828s 911ms/step - loss: 0.0284 - accuracy: 0.9997 - val_loss: 1.1774 - val_accuracy: 0.7716
# Epoch 8/10
# 909/909 [==============================] - 828s 911ms/step - loss: 0.0245 - accuracy: 0.9999 - val_loss: 1.1357 - val_accuracy: 0.7722
# Epoch 9/10
# 909/909 [==============================] - 828s 910ms/step - loss: 0.0216 - accuracy: 0.9999 - val_loss: 1.1133 - val_accuracy: 0.7721
# Epoch 10/10
# 909/909 [==============================] - 827s 910ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 1.0886 - val_accuracy: 0.7736

# %%
loss, acc = model3.evaluate(test_data)
# Out:
# 101/101 [==============================] - 41s 402ms/step - loss: 1.0886 - accuracy: 0.7736

# %%
print("Test Accuracy:",round(acc*100,2),"%","\nTest Loss:",loss)
# Out:
# Test Accuracy: 77.36 %
# Test Loss: 1.0886189937591553
